# %% [markdown]
# # 01 - Data Exploration
# ## 5G Traffic Classification Dataset
# **Team:** Gradient_Issues

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scripts.preprocess import DataLoader, plot_eda

# %%
dataloader = DataLoader('../data/5g_traffic_classification.csv')
print(f"Dataset shape: {dataloader.df.shape}")
print(f"Columns: {list(dataloader.df.columns)}")
print(f"Number of classes: {len(dataloader.label_encoder.classes_)}")
print(f"Classes: {list(dataloader.label_encoder.classes_)}")

# %%
dataloader.df.head()

# %%
dataloader.df.info()

# %%
dataloader.df.describe()

# %%
plot_eda(dataloader)

# %%
# Check for missing values
missing = dataloader.df.isnull().sum()
missing[missing > 0]

# %%
# Class distribution
dataloader.df['label'].value_counts()
